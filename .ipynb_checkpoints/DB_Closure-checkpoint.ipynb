# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:/Users/jwolf/Documents/MEGA/03_Doutoramento/06_Base de dados/School closure/Average income_employed.csv", encoding="ANSI", sep=';', header = 0)
df.drop('2011',axis=1, inplace=True)
df
# Out:
#      Code                      Name     2012     2010     2009     2008  \
# 0    1705           Mondim de Basto   741,44   703,75   616,65   604,49
# 1     404  Freixo de Espada à Cinta   683,48   670,82   631,77   582,91
# 2    1309         Paços de Ferreira   712,85   691,07    658,4   640,74
# 3    1305                   Lousada   696,85   692,27    676,4   645,94
# 4     305         Celorico de Basto    730,9   703,81   667,12   631,18
# 5     510               Vila de Rei   692,12   666,55   652,26   649,72
# 6     506                   Oleiros   749,02   718,24   669,52   649,92
# 7     314                    Vizela   722,87   684,86   645,34   639,99
# 8    1813                   Resende   769,12   733,33   673,97   634,41
# 9    1303                Felgueiras   711,69    691,1   673,13    650,9
# 10   1818               Sernancelhe   717,62   699,77   645,16   618,61
# 11    307                      Fafe   728,14   707,58   673,87   661,68
# ...
